# %% [markdown]
# ### Load Full E-commerce Data

# %%
# Load October CSV data
oct_events = spark.read.csv(
    "/Volumes/workspace/eccomerce/ecommerce_data/2019-Oct.csv",
    header=True,
    inferSchema=True
)

# Load November CSV data
nov_events = spark.read.csv(
    "/Volumes/workspace/eccomerce/ecommerce_data/2019-Nov.csv",
    header=True,
    inferSchema=True
)

# %% [markdown]
# ### Rename Datasets

# %%
# Rename October DataFrame
df_oct = oct_events

# Rename November DataFrame
df_nov = nov_events

# %% [markdown]
# ### 1.Create Incremental Data
# ### Step 1: Create Incremental Dataset (New & Updated Records)
#
# This step simulates incoming incremental data.
# The dataset contains:
# - Records that already exist (to test updates)
# - Completely new records (to test inserts)
#
# This temporary view will be used as the source for the MERGE operation.

# %%
# %sql
-- Create incremental data (new + updated records)
CREATE OR REPLACE TEMP VIEW sales_updates AS
SELECT 101 AS order_id, 'Laptop' AS product, 3 AS qty, 1250 AS price
UNION ALL
SELECT 105 AS order_id, 'Keyboard' AS product, 2 AS qty, 80 AS price;

# %% [markdown]
# ### View Incremental Data
# ### Step 2: Validate Incremental Data
#
# Querying the temporary view to verify the incremental records
# before merging them into the Delta table.

# %%
# %sql
SELECT * FROM sales_updates;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product</th><th>qty</th><th>price</th></tr></thead><tbody><tr><td>101</td><td>Laptop</td><td>3</td><td>1250</td></tr><tr><td>105</td><td>Keyboard</td><td>2</td><td>80</td></tr></tbody></table></div>

# %% [markdown]
# ### MERGE Incremental Data

# %%
# %sql
-- Apply incremental updates and inserts into Delta table
MERGE INTO sales_delta t
USING sales_updates s
ON t.order_id = s.order_id
WHEN MATCHED THEN
  UPDATE SET *
WHEN NOT MATCHED THEN
  INSERT *;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ### Verify MERGE Result

# %%
# %sql
-- Validate final table after merge
SELECT * FROM sales_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>product</th><th>qty</th><th>price</th></tr></thead><tbody><tr><td>105</td><td>Keyboard</td><td>2</td><td>80</td></tr><tr><td>101</td><td>Laptop</td><td>3</td><td>1250</td></tr></tbody></table></div>

# %% [markdown]
# ### 2.Query historical versions

# %% [markdown]
# ### i.Check Table History Time Travel Setup

# %%
# %sql
-- View Delta table version history
DESCRIBE HISTORY sales_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>2</td><td>2026-01-13T07:00:14.000Z</td><td>73029697663450</td><td>ruchiwange07@gmail.com</td><td>MERGE</td><td>Map(predicate -> ["(order_id#13667 = order_id#13659)"], clusterBy -> [], matchedPredicates -> [{"actionType":"update"}], statsOnLoad -> false, notMatchedBySourcePredicates -> [], notMatchedPredicates -> [{"actionType":"insert"}])</td><td>null</td><td>List(533720317512728)</td><td>0113-064726-rmq3pplr-v2n</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 2, numTargetBytesAdded -> 3853, numTargetBytesRemoved -> 2405, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 2, executionTimeMs -> 3991, materializeSourceTimeMs -> 137, numTargetRowsInserted -> 0, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 1797, numTargetRowsUpdated -> 2, numOutputRows -> 2, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 2, numTargetFilesRemoved -> 2, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 1953)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>1</td><td>2026-01-13T06:58:12.000Z</td><td>73029697663450</td><td>ruchiwange07@gmail.com</td><td>MERGE</td><td>Map(predicate -> ["(order_id#13350 = order_id#13342)"], clusterBy -> [], matchedPredicates -> [{"actionType":"update"}], statsOnLoad -> true, notMatchedBySourcePredicates -> [], notMatchedPredicates -> [{"actionType":"insert"}])</td><td>null</td><td>List(533720317512728)</td><td>0113-064726-rmq3pplr-v2n</td><td>0</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 2, numTargetBytesAdded -> 2405, numTargetBytesRemoved -> 0, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 0, executionTimeMs -> 3455, materializeSourceTimeMs -> 252, numTargetRowsInserted -> 2, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 1285, numTargetRowsUpdated -> 0, numOutputRows -> 2, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 2, numTargetFilesRemoved -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 1787)</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr><tr><td>0</td><td>2026-01-13T06:58:01.000Z</td><td>73029697663450</td><td>ruchiwange07@gmail.com</td><td>CREATE TABLE</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true","delta.writePartitionColumnsToParquet":"true","delta.enableRowTracking":"true","delta.rowTracking.materializedRowCommitVersionColumnName":"_row-commit-version-col-cd85bdf0-18b8-4e60-a08d-a7295a472e2c","delta.rowTracking.materializedRowIdColumnName":"_row-id-col-380183c4-e824-4fb4-aa93-ded91bd4575b"}, statsOnLoad -> false)</td><td>null</td><td>List(533720317512728)</td><td>0113-064726-rmq3pplr-v2n</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/17.3.x-aarch64-photon-scala2.13</td></tr></tbody></table></div>

# %% [markdown]
# ### 3.OPTIMIZE Delta Table

# %%
# %sql
-- Optimize entire Delta table (no partition column)
OPTIMIZE sales_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, null, null, 0, 0, 1, 1, true, 0, 0, 1768289372822, 1768289373303, 8, 0, null, List(0, 0), null, 4, 4, 0, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# Observation:
# The OPTIMIZE command completed successfully.
# No files were compacted as the table did not contain small or fragmented files at this stage.
# This is expected for low-volume or already optimized Delta tables.

# %% [markdown]
# ### 4.Clean Old Files

# %%
# %sql
-- Clean obsolete files from Delta table (safe retention)
VACUUM sales_delta RETAIN 168 HOURS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td></td></tr></tbody></table></div>

# %% [markdown]
# Observation:
# VACUUM executed successfully.
# No obsolete files were found for deletion, which is expected for a newly created
# or low-volume Delta table within the retention period.

# %% [markdown]
# ### Analytics & AI Readiness Preview

# %%
# %sql
SELECT product, COUNT(*) AS orders
FROM sales_delta
GROUP BY product;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>orders</th></tr></thead><tbody><tr><td>Laptop</td><td>1</td></tr><tr><td>Keyboard</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# ### AI Readiness Note
#
# The Delta table created in this notebook is optimized, versioned, and governed.
# With incremental MERGE,OPTIMIZE, and VACUUM applied,
# the dataset is now ready for downstream AI, ML, and analytics workloads
# without additional preprocessing.

# %% [markdown]
# ## Conclusion:
# This notebook demonstrates end-to-end Delta Lake lifecycle management
# aligned with AI-ready data engineering best practices.
